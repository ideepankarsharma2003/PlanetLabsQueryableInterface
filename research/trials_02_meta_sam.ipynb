# %%
import os; os.chdir("..")

# %%
from transformers import pipeline
from PIL import Image
import requests

url = "research/images/bab-e-mandab.jpg"
image = Image.open(url)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x415>

# %%
semantic_segmentation = pipeline("image-segmentation", "badmatr11x/semantic-image-segmentation")
results = semantic_segmentation(image)
results
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# /home/ubuntu/.local/lib/python3.10/site-packages/transformers/models/segformer/image_processing_segformer.py:101: FutureWarning: The `reduce_labels` parameter is deprecated and will be removed in a future version. Please use `do_reduce_labels` instead.
# ...

# %%
for i in results:
    print(i)
# Out:
# {'score': None, 'label': 'building', 'mask': <PIL.Image.Image image mode=L size=612x415 at 0x7F785AC0B7C0>}
# {'score': None, 'label': 'sky', 'mask': <PIL.Image.Image image mode=L size=612x415 at 0x7F785AC0BB80>}
# {'score': None, 'label': 'tree', 'mask': <PIL.Image.Image image mode=L size=612x415 at 0x7F785AC0B940>}
# {'score': None, 'label': 'road', 'mask': <PIL.Image.Image image mode=L size=612x415 at 0x7F785AC0BBE0>}
# {'score': None, 'label': 'sidewalk', 'mask': <PIL.Image.Image image mode=L size=612x415 at 0x7F785AC0B8E0>}
# {'score': None, 'label': 'car', 'mask': <PIL.Image.Image image mode=L size=612x415 at 0x7F785AC0B880>}
# {'score': None, 'label': 'signboard', 'mask': <PIL.Image.Image image mode=L size=612x415 at 0x7F785AC0BAC0>}
# {'score': None, 'label': 'streetlight', 'mask': <PIL.Image.Image image mode=L size=612x415 at 0x7F785AC0B820>}

# %%
semantic_segmentation

# %%
from  transformers.pipelines.image_segmentation import ImageSegmentationPipeline

# %%
ImageSegmentationPipeline
# Out:
# transformers.pipelines.image_segmentation.ImageSegmentationPipeline

# %%
masked_image= results[5]['mask']
(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x415>

# %%
(masked_image)
# Out:
# <PIL.Image.Image image mode=L size=612x415>
